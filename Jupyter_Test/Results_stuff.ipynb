# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pandas as pd
import matplotlib.pyplot as plt

# 假设您的CSV文件路径为 'data.csv'
tr_df = pd.read_csv('../../Results_training/Res18_07075_windowed_only_liver_2D/train.csv',header=0)
val_df = pd.read_csv('../../Results_training/Res18_07075_windowed_only_liver_2D/val.csv',header=0)
val_accur = val_df[7::9].iloc[:,0].values.tolist()

val_accur = [float(i) for i in val_accur]

# %%
val_df_0_pre = val_df[5::9].iloc[:,0].values.tolist()
val_df_0_recall = val_df[6::9].iloc[:,0].values.tolist()

val_df_0_pre = [float(i) for i in val_df_0_pre]
val_df_0_recall = [float(i) for i in val_df_0_recall]

val_df_1_pre = val_df[5::9].iloc[:,1].values.tolist()
val_df_1_recall = val_df[6::9].iloc[:,1].values.tolist()

val_df_1_pre = [float(i) for i in val_df_1_pre]
val_df_1_recall = [float(i) for i in val_df_1_recall]

# %%
plt.plot(val_df_1_pre, label='Precision')
plt.plot(val_df_1_recall,label='Recall')
plt.xlabel('Epoch')
plt.ylabel('Precision and Recall')
plt.legend()
plt.title('Precision/Recall of PVP')
# Out:
# Text(0.5, 1.0, 'Precision/Recall of PVP')

# %%
val_accur = [float(i) for i in val_accur]
plt.plot(val_accur)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy of Only_Liver')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
tr_0_acc = tr_df.iloc[2::6,:]
# Out:
#      epoch  class_0_tp          class_0_fp          class_0_tn  \
# 2        1           0  0.5655538870278388   0.581275657850461
# 8        2           1  0.6309202718739887  0.6195172195337377
# 14   epoch  class_0_tp          class_0_fp          class_0_tn
# 20       5      2875.0              1390.0              3017.0
# 26   epoch    class_id                  f1                 auc
# ..     ...         ...                 ...                 ...
# 470     95      3375.0               732.0              3849.0
# 476  epoch    class_id                  f1                 auc
# 482     97           0  0.8017322097378278  0.8111090489539561
# 488     98           1  0.8144429013994231   0.806732720240211
# 494  epoch  class_0_tp          class_0_fp          class_0_tn
#
#              class_0_fn          class_1_tp          class_1_fp  class_1_tn  \
# 2    0.5817393238434164   0.577767288175596  0.5538461538461539         NaN
# ...

# %%
plt.plot(tr_0_acc.iloc[:,0], label='Validation_Accuracy')

# %%
val_df.iloc[9::9]
# Out:
#     epoch class_0_tp class_0_fp class_0_tn class_0_fn class_1_tp class_1_fp  \
# 81     10      880.0      200.0      515.0      626.0      515.0      626.0
# 162    19      771.0      165.0      550.0      735.0      550.0      735.0
# 243    28      934.0      302.0      413.0      572.0      413.0      572.0
# 324    37     1116.0      331.0      384.0      390.0      384.0      390.0
# 405    46     1135.0      354.0      361.0      371.0      361.0      371.0
# 486    55     1103.0      252.0      463.0      403.0      463.0      403.0
# 567    64     1116.0      287.0      428.0      390.0      428.0      390.0
# 648    73     1170.0      318.0      397.0      336.0      397.0      336.0
# 729    82     1145.0      309.0      406.0      361.0      406.0      361.0
# 810    91     1178.0      317.0      398.0      328.0      398.0      328.0
# 891   100     1154.0      295.0      420.0      352.0      420.0      352.0
#
# ...

# %%
tr_0_precision = tr_df.iloc[2::6,:].iloc[:,5].tolist()
tr_0_recall = tr_df.iloc[2::6,:].iloc[:,6].tolist()

tr_1_precision = tr_df.iloc[3::6,:].iloc[:,5].tolist()
tr_1_recall = tr_df.iloc[3::6,:].iloc[:,6].tolist()

tr_2_precision = tr_df.iloc[4::6,:].iloc[:,5].tolist()
tr_2_recall = tr_df.iloc[4::6,:].iloc[:,6].tolist()

#round
# tr_0_precision = [round(float(i),4) for i in tr_0_precision]
# tr_0_recall = [round(float(i),4) for i in tr_0_recall]
# tr_1_precision = [round(float(i),4) for i in tr_1_precision]
# tr_1_recall = [round(float(i),4) for i in tr_1_recall]
# tr_2_precision = [round(float(i),4) for i in tr_2_precision]
# tr_2_recall = [round(float(i),4) for i in tr_2_recall]

#Plot
plt.figure(figsize=(10, 6))
plt.plot(tr_0_precision, label='0_Precision')
plt.plot(tr_0_recall, label='0_Recall')
plt.xlabel('Epoch')
plt.ylabel('Precision/Recall')



plt.title('Res10_07075_windowed')
plt.legend()

# %%
# 类别 0
plt.plot(tr_0_precision, label='Class 0 Precision')
plt.plot(tr_0_recall, label='Class 0 Recall')

# 类别 1
#plt.plot(tr_1_precision, label='Class 1 Precision')
#plt.plot(tr_1_recall, label='Class 1 Recall')



# 类别 2
#plt.plot(tr_2_precision, label='Class 2 Precision')
#plt.plot(tr_2_recall, label='Class 2 Recall')

# 添加图例, 位置为右下角
plt.legend(loc='lower right')

# 添加坐标轴标题
plt.xlabel('Epochs')
plt.ylabel('Value')

# 添加图表标题
plt.title('Precision and Recall by Class')
# Out:
# Text(0.5, 1.0, 'Precision and Recall by Class')

# %%
tr_df = tr_df[pd.to_numeric(tr_df['loss'], errors='coerce').notnull()]

# 确保'loss'列只包含数字
tr_df['loss'] = pd.to_numeric(tr_df['loss'])

tr_loss = tr_df['loss'].unique()


val_df = val_df[pd.to_numeric(val_df['loss'], errors='coerce').notnull()]

# 确保'loss'列只包含数字
val_df['loss'] = pd.to_numeric(val_df['loss'])

val_loss = val_df['loss'].unique()
# Out:
# C:\Users\098986\AppData\Local\Temp\ipykernel_2676\2243215097.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tr_df['loss'] = pd.to_numeric(tr_df['loss'])

# %%
tr_loss[0:100]
# Out:
# array([0.68078295, 0.64691466, 0.63371697, 0.62246578, 0.60669693,
#        0.59852824, 0.58961489, 0.58149933, 0.58929777, 0.58219573,
#        0.57454577, 0.57179763, 0.5656107 , 0.57088851, 0.56218919,
#        0.54636036, 0.54760364, 0.54319647, 0.52899395, 0.53194856,
#        0.52371671, 0.52143947, 0.52727552, 0.51709086, 0.52124801,
#        0.5130791 , 0.51416553, 0.50151905, 0.49649644, 0.4886964 ,
#        0.50004598, 0.4976226 , 0.4825082 , 0.48704927, 0.47163972,
#        0.46795334, 0.44410528, 0.44109343, 0.44381191, 0.43654698,
#        0.43168196, 0.42985701, 0.4340977 , 0.42341346, 0.43424442,
#        0.430675  , 0.42423237, 0.43043748, 0.42509598, 0.43040579,
#        0.42610956, 0.41855229, 0.41021975, 0.41492172, 0.41890375,
#        0.42308811, 0.41808835, 0.41943914, 0.40829538, 0.41220206,
#        0.41518944, 0.41068261, 0.40519907, 0.40848879, 0.41179646,
#        0.39859189, 0.39792154, 0.40505415, 0.39847377, 0.40289316,
# ...

# %%
plt.plot(tr_loss[0:100], label='Training Loss')
plt.plot(val_loss[0:100], label='Validation Loss')
plt.legend()
plt.title('Window_07075_Only_Liver_2D')
# Out:
# Text(0.5, 1.0, 'Window_07075_Only_Liver_2D')

# %%
accu = []
# Out:
#   Cell In[174], line 2
#     0.4
#     ^
# SyntaxError: invalid syntax

# %%
plt.figure()



tr_acc = tr_df['accuracy']
val_acc = val_df['accuracy']

# %%
acc= pd.read_table('../../Results_training/Res18_07075_windowed_2D/acc.txt',header=None)
acc.values[0:100].reshape(100).tolist()


#Plot

plt.figure(figsize=(10, 6))
plt.plot(acc.values[0:100].reshape(100).tolist(), label='Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Res18_07075_windowed_2D')
plt.legend()

# %%
tr_acc_lst = tr_acc.tolist()
#keep .2f
tr_acc_lst = [round(float(elem), 2) for elem in tr_acc_lst]
tr_acc_lst = [round(elem, 2) for elem in tr_acc_lst]


val_acc_lst = val_acc.tolist()
#keep .2f
val_acc_lst = [round(float(elem), 2) for elem in val_acc_lst]
val_acc_lst = [round(elem, 2) for elem in val_acc_lst]

# %%
plt.plot(tr_acc_lst, label='Training Accuracy')
plt.plot(val_acc_lst, label='Validation Accuracy')
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# 设置y轴的主要刻度间隔为0.2
plt.gca().yaxis.set_major_locator(MultipleLocator(0.05))

# 设置y轴的刻度标签格式为小数点后两位
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Over Time')
plt.legend()
plt.tight_layout()
plt.title('Resnet10_Window_07075')
plt.show()

# %%
# Out:
#     epoch class_0_tp class_0_fp class_0_tn class_0_fn class_1_tp class_1_fp  \
# 0       1       27.0       49.0       88.0       46.0       21.0       43.0
# 6       2       27.0       51.0       89.0       43.0       11.0       24.0
# 12      3        6.0       23.0      126.0       55.0       40.0       69.0
# 18      4       26.0       41.0       93.0       50.0       14.0       45.0
# 24      5       44.0       56.0       84.0       26.0       24.0       36.0
# ..    ...        ...        ...        ...        ...        ...        ...
# 570    96       41.0       37.0      109.0       23.0       42.0       29.0
# 576    97       42.0       35.0      111.0       22.0       41.0       38.0
# 582    98       44.0       27.0      103.0       36.0       33.0       35.0
# 588    99       44.0       37.0      101.0       28.0       35.0       32.0
# 594   100       41.0       32.0      112.0       25.0       37.0       33.0
#
# ...

# %%
df
# Out:
#      epoch class_0_tp           class_0_fp          class_0_tn  \
# 0        1       27.0                 49.0                88.0
# 1    epoch   class_id                   f1                 auc
# 2        1          0  0.36241610738255026  0.5060993900609938
# 3        1          1   0.3230769230769231  0.5097853535353535
# 4        1          2   0.2695035460992907  0.4503495794913366
# ..     ...        ...                  ...                 ...
# 594    100       41.0                 32.0               112.0
# 595  epoch   class_id                   f1                 auc
# 596    100          0   0.5899280575539569  0.6994949494949494
# 597    100          1   0.5211267605633804  0.6373792270531401
# 598    100          2   0.5611510791366906  0.6693840579710144
#
#              class_0_fn           class_1_tp          class_1_fp class_1_tn  \
# 0                  46.0                 21.0                43.0      101.0
# ...
